# %%
import brainsss
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#from sklearn.cluster import AgglomerativeClustering
import scipy
import time
import h5py
import ants
import nibabel as nib
from scipy.ndimage import uniform_filter, gaussian_filter
import shutil
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.image import grid_to_graph
import gc
import sys
import warnings
from scipy.ndimage import gaussian_filter1d,gaussian_filter
from scipy.signal import butter, sosfiltfilt, filtfilt, freqz,iirnotch
import cv2
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
from scipy.ndimage import zoom
from sklearn.mixture import GaussianMixture
import sklearn
import pickle

# %%
func_path = '/oak/stanford/groups/trc/data/Ilana/2P/data/'
home_path = '/oak/stanford/groups/trc/data/Ilana/2P/data/later/'
later_dir = '/oak/stanford/groups/trc/data/Ilana/2P/data/later/temp_filter'
cluster_dir = os.path.join(later_dir, 'clustering')
save_dir=os.path.join(later_dir,'figs')
scratch_dir = '/scratch/users/ilanazs'

event='prev_behavior'

warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
fly_num=[226,227,228,234,239,240,241,242,249,250]

# %%
for num in fly_num:
    fly_name=f'fly_{num}'
    temp_path=os.path.join(scratch_dir, fly_name)
    for file in os.listdir(temp_path):
        if event in file:
            print(file)
#             os.remove(os.path.join(temp_path,file))
#             take_away=file.replace('5sec_','')
#             fix=take_away.split('.')[0]
#             new=os.path.join(temp_path,fix + '_5sec.h5')
#             os.rename(os.path.join(temp_path,file),new)
# Out:
# ts_rel_odd_mask_1_non_non_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_non_flat_prev_behavior.h5
# filter_needs_1_flat_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_non_prev_behavior.h5
# filter_needs_2_inc_dec_prev_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# filter_needs_2_inc_non_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# filter_needs_1_non_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_non_dec_prev_behavior.h5
# filter_needs_1_non_dec_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_prev_behavior.h5
# filter_needs_2_flat_non_prev_behavior.h5
# ts_rel_odd_mask_2_non_dec_prev_behavior.h5
# filter_needs_2_dec_dec_prev_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_1_non_inc_prev_behavior.h5
# ts_rel_odd_mask_2_non_non_prev_behavior.h5
# filter_needs_1_flat_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_2_non_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_1_inc_non_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_prev_behavior.h5
# filter_needs_1_non_flat_prev_behavior.h5
# filter_needs_1_non_non_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_non_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_non_prev_behavior.h5
# filter_needs_2_non_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# filter_needs_1_dec_non_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_dec_non_prev_behavior.h5
# ts_rel_odd_mask_2_non_flat_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# filter_needs_2_dec_non_prev_behavior.h5
# filter_needs_2_non_non_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_non_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_non_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_non_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# filter_needs_1_inc_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# filter_needs_2_non_inc_prev_behavior.h5
# filter_needs_2_flat_inc_prev_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# filter_needs_1_flat_non_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_2_flat_dec_prev_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# filter_needs_1_flat_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# filter_needs_1_inc_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# filter_needs_2_inc_dec_prev_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# filter_needs_2_dec_dec_prev_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# filter_needs_2_inc_dec_prev_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# filter_needs_1_flat_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_2_flat_dec_prev_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# filter_needs_1_flat_dec_prev_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# filter_needs_2_inc_flat_prev_prev_behavior.h5
# filter_needs_1_dec_dec_prev_prev_behavior.h5
# filter_needs_1_inc_flat_prev_prev_behavior.h5
# filter_needs_2_flat_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_dec_dec_prev_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# filter_needs_1_inc_dec_prev_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# filter_needs_1_inc_dec_prev_behavior.h5
# filter_needs_1_inc_inc_prev_prev_behavior.h5
# filter_needs_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_inc_dec_prev_behavior.h5
# filter_needs_2_flat_dec_prev_behavior.h5
# filter_needs_1_dec_inc_prev_behavior.h5
# filter_needs_1_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_2_inc_flat_prev_behavior.h5
# filter_needs_1_flat_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_1_dec_flat_prev_behavior.h5
# filter_needs_2_flat_inc_prev_behavior.h5
# filter_needs_2_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_dec_prev_behavior.h5
# ts_rel_odd_mask_2_dec_flat_prev_behavior.h5
# filter_needs_2_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_inc_inc_prev_behavior.h5
# filter_needs_1_inc_flat_prev_behavior.h5
# ts_rel_odd_mask_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_flat_prev_behavior.h5
# filter_needs_2_dec_inc_prev_behavior.h5
# ts_rel_odd_mask_2_flat_flat_prev_behavior.h5
# filter_needs_2_flat_flat_prev_behavior.h5
# filter_needs_1_dec_flat_prev_behavior.h5
# filter_needs_1_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_dec_inc_prev_behavior.h5
# filter_needs_1_inc_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_behavior.h5
# filter_needs_1_flat_flat_prev_behavior.h5
# ts_rel_odd_mask_2_flat_dec_prev_behavior.h5
# ts_rel_odd_mask_1_inc_inc_prev_behavior.h5
# filter_needs_2_dec_flat_prev_behavior.h5
# filter_needs_1_dec_dec_prev_behavior.h5
# filter_needs_2_dec_inc_prev_prev_behavior.h5
# ts_rel_odd_mask_1_dec_dec_prev_behavior.h5
# ts_rel_odd_mask_2_flat_inc_prev_behavior.h5
# filter_needs_2_inc_inc_prev_prev_behavior.h5

# %%
for file in os.listdir(later_dir):
    if event in file:
        print(file)
# Out:
# behave_dict_total_prev_behavior.pkl
