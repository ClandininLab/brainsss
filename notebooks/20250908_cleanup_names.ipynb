# %%
import brainsss
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#from sklearn.cluster import AgglomerativeClustering
import scipy
import time
import h5py
import ants
import nibabel as nib
from scipy.ndimage import uniform_filter, gaussian_filter
import shutil
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.image import grid_to_graph
import gc
import sys
import warnings
from scipy.ndimage import gaussian_filter1d,gaussian_filter
from scipy.signal import butter, sosfiltfilt, filtfilt, freqz,iirnotch
import cv2
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
from scipy.ndimage import zoom
from sklearn.mixture import GaussianMixture
import sklearn
import pickle

# %%
func_path = '/oak/stanford/groups/trc/data/Ilana/2P/data/'
home_path = '/oak/stanford/groups/trc/data/Ilana/2P/data/later/'
later_dir = '/oak/stanford/groups/trc/data/Ilana/2P/data/later/temp_filter'
cluster_dir = os.path.join(later_dir, 'clustering')
save_dir=os.path.join(later_dir,'figs')

step_size=100

event='10flies'

warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
fly_num=[226,227,228,233,234,239,240,241,242,249,250]

# %%
for num in fly_num:
    fly_name=f'fly_{num}'
    temp_path=os.path.join(func_path, fly_name, 'temp_filter')
    for file in os.listdir(temp_path):
        if '5sec' in file:
            print(file)
#             take_away=file.replace('5sec_','')
#             fix=take_away.split('.')[0]
#             new=os.path.join(temp_path,fix + '_5sec.h5')
#             os.rename(os.path.join(temp_path,file),new)
# Out:
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_flat_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_total_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_inc_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_dec_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_dec_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_total_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_flat_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_inc_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_flat_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_dec_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_total_10flies_5sec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_inc_10flies_5sec.h5
