# %%
import brainsss
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#from sklearn.cluster import AgglomerativeClustering
import scipy
import time
import h5py
import ants
import nibabel as nib
from scipy.ndimage import uniform_filter, gaussian_filter
import shutil
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.image import grid_to_graph
import gc
import sys
import warnings
from scipy.ndimage import gaussian_filter1d,gaussian_filter
from scipy.signal import butter, sosfiltfilt, filtfilt, freqz,iirnotch
import cv2
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
from scipy.ndimage import zoom
from sklearn.mixture import GaussianMixture
import sklearn
import pickle
# Out:
# /home/users/ilanazs/.local/lib/python3.6/site-packages/ants/viz/render_surface_function.py:16: UserWarning:
#
# Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function

# %%
func_path = '/oak/stanford/groups/trc/data/Ilana/2P/data/'
home_path = '/oak/stanford/groups/trc/data/Ilana/2P/data/later/'
later_dir = '/oak/stanford/groups/trc/data/Ilana/2P/data/later/temp_filter'
cluster_dir = os.path.join(later_dir, 'clustering')
save_dir=os.path.join(later_dir,'figs')

step_size=100

event='best'

warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
fly_num=[208,209, 210,217,218,226,227,228,233,234,239,240,241,242,249,250]

# %%
# del_dir=os.path.join(later_dir, 'total')
# for file in os.listdir(del_dir):
#     if 'STA' not in file and '.h5' in file:
#         os.remove(os.path.join(del_dir,file))
#     else:
#         print(file)

# %%
# final_file1='functional_channel_1_moco_warp_blurred_hpf_dff.h5'
# final_file2='functional_channel_2_moco_warp_blurred_hpf_dff.h5'

# for folder in os.listdir(func_path):
#     if 'fly' in folder and int(folder[-3:]) in fly_num:
#         fly_folder = os.path.join(func_path,folder, 'temp_filter')
#         if os.path.exists(fly_folder):
#             for file in os.listdir(fly_folder):
# #                 print(file)
#                 if '10flies' in file:
#                     os.remove(os.path.join(fly_folder,file))
#                 else:
#                     print(file)
# Out:
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_dec.h5
# filter_needs_dec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_flat.h5
# ts_rel_odd_mask_inc.h5
# filter_needs_flat.h5
# filter_needs_total.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_total.h5
# filter_needs_inc.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_inc.h5
# filter_needs.h5
# ts_rel_odd_mask.h5
# ts_rel_odd_mask_dec.h5
# ts_rel_odd_mask_flat.h5
# ts_rel_odd_mask_total.h5
# filter_needs.h5
# ts_rel_odd_mask_total.h5
# ts_rel_odd_mask_dec.h5
# ts_rel_odd_mask.h5
# filter_needs_inc.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_dec.h5
# filter_needs_dec.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_flat.h5
# functional_channel_2_moco_warp_blurred_hpf_dff_filtered_inc.h5
# filter_needs_flat.h5
# filter_needs_total.h5
# ts_rel_odd_mask_inc.h5
# ...
